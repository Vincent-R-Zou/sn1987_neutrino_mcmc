# %%
import matplotlib.pyplot as plt
import pickle

# 1. Load the figure object
with open('F:/Neutrino_SI/3d_plots/my_3d_plot.pkl', 'rb') as file:
    fig = pickle.load(file)

# 2. Show the interactive window!
plt.show()
