# %%
# import SignalRate_2d_osc as s2d
import SignalRate_1d as s1d
import numpy as np
from scipy.optimize import minimize
import definition as df

percision = 64
E_range = (5, 50)
t_range = (0.01, 30)

E_min, E_max = E_range
t_min, t_max = t_range

range_k = [t_range, E_range,  (-1, 1)]

def SR_HK(t, E_e, c, *args):

    R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu = args

    # N_K = 1.43e32 # for K-II

    N_K = 1.26e34 # for HK

    # eff_K = 0.932/np.sqrt(1+(34/(12-7*E_e+E_e**2))**2)        # This one is not well-fitted

    eff_K = 1

    ret = N_K * s1d.cs_at_c(c, s1d.E_nu(E_e, c)) * s1d.Flux_total(t, s1d.E_nu(E_e, c), R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu) * s1d.E_nu_at_E_e(E_e, c) * eff_K

    return ret


params = [15, 5, 5, 0.5, 2, 0.6, -4, -12]


def minimize_sr(vars):
    t, E = vars
    return - SR_HK(t, E, 0,*params)

ret = minimize(minimize_sr, x0=[0.1, 10], bounds=(t_range, E_range), method='L-BFGS-B')

print('f_max and coordinates', -ret.fun, ret.x)

f_max = -ret.fun
num_samples = df.gl3_integrate(SR_HK, range_k, percision, args=params)
print('num_samples', num_samples)

def sample_rejection(flux_func, E_range, t_range, f_max, num_samples, *args):
    samples = []
    
    while len(samples) < num_samples:
        # 1. Propose E and t uniformly within your bounds
        E_prop = np.random.uniform(E_range[0], E_range[1])
        t_prop = np.random.uniform(t_range[0], t_range[1])
        
        # 2. Draw a uniform height to test against the flux
        u = np.random.uniform(0, f_max)
        
        # 3. Accept if the test height is under the distribution surface
        if u < flux_func(t_prop, E_prop, 0, *args):
            samples.append((t_prop, E_prop))
            
    return np.array(samples)

t_samples, E_samples = sample_rejection(SR_HK, E_range, t_range, f_max, num_samples, *params).T

np.save(r'F:/Neutrino_SI/Data/samples_HK_1d.npy', np.array([t_samples, E_samples]).T)
# Out:
# f_max and coordinates 102.77173206970421 [1.00000000e-02 1.10282191e+01]
# num_samples 2027.3080685339655
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 65
#      61             samples.append((t_prop, E_prop))
#      63     return np.array(samples)
# ---> 65 t_samples, E_samples = sample_rejection(SR_HK, E_range, t_range, f_max, num_samples, *params).T
#      67 np.save(r'F:/Neutrino_SI/Data/samples_HK_1d.npy', np.array([t_samples, E_samples]).T)
#
# Cell In[4], line 60, in sample_rejection(flux_func, E_range, t_range, f_max, num_samples, *args)
#      57     u = np.random.uniform(0, f_max)
#      59     # 3. Accept if the test height is under the distribution surface
# ---> 60     if u < flux_func(t_prop, E_prop, 0, *args):
#      61         samples.append((t_prop, E_prop))
#      63 return np.array(samples)
#
# Cell In[4], line 28, in SR_HK(t, E_e, c, *args)
#      24 # eff_K = 0.932/np.sqrt(1+(34/(12-7*E_e+E_e**2))**2)        # This one is not well-fitted
#      26 eff_K = 1
# ---> 28 ret = N_K * s1d.cs_at_c(c, s1d.E_nu(E_e, c)) * s1d.Flux_total(t, s1d.E_nu(E_e, c), R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu) * s1d.E_nu_at_E_e(E_e, c) * eff_K
#      30 return ret
#
# File F:\Neutrino_SI\Pycode\SignalRate_1d.py:153, in Flux_total(t, E_nu, *args)
#     150 flux = flux_accretion + (1 - j_kt(t)) *flux_cooling
#     152 if log_scale:
# --> 153     return flux * np.exp(neutrino_new_log.d_phi(E_nu, m_phi, lambda_nu))
#     154 else:
#     155     return flux * np.exp(neutrino_new.d_phi(E_nu, m_phi, lambda_nu))
#
# File F:\Neutrino_SI\Pycode\neutrino_new_log.py:66, in d_phi(E_nu, log_m_phi, log_lambda_nu)
#      62 f_FD = lambda E_1:  1/(1+df.safe_exp(E_1/T_nu))
#      64 integ_part = lambda c, E_1: cross_section(E_space, log_m_phi, log_lambda_nu, c, E_1) * f_FD(E_1) * E_1**2/ (4*np.pi**2)
# ---> 66 ratio = -df.gl2_integrate_vector(integ_part, [(-1, 1), (E_1_min, 0.002)], n=200)
#      68 ret = IUS(E_space, ratio)(E_nu)* Distance_SN1987 * np.sqrt(1/coefficient)
#      70 return np.clip(ret, None, 0)
#
# File F:\Neutrino_SI\Pycode\definition.py:179, in gl2_integrate_vector(f_vec, bounds, n)
#     176 Y = half_width_y * gy_b + center_y
#     178 # F shape: (nx, ny, N)
# --> 179 F = f_vec(X, Y)
#     181 # ---------------------------------------------------------
#     182 # 6. INTEGRATION (WEIGHTED SUM)
#     183 # ---------------------------------------------------------
#     184 WX = wx_b * half_width_x
#
# File F:\Neutrino_SI\Pycode\neutrino_new_log.py:64, in d_phi.<locals>.<lambda>(c, E_1)
#      60 # print("E_1_min:", E_1_min)
#      62 f_FD = lambda E_1:  1/(1+df.safe_exp(E_1/T_nu))
# ---> 64 integ_part = lambda c, E_1: cross_section(E_space, log_m_phi, log_lambda_nu, c, E_1) * f_FD(E_1) * E_1**2/ (4*np.pi**2)
#      66 ratio = -df.gl2_integrate_vector(integ_part, [(-1, 1), (E_1_min, 0.002)], n=200)
#      68 ret = IUS(E_space, ratio)(E_nu)* Distance_SN1987 * np.sqrt(1/coefficient)
#
# File F:\Neutrino_SI\Pycode\neutrino_new_log.py:62, in d_phi.<locals>.<lambda>(E_1)
#      58 E_1_min = np.clip((m_phi**2 - m_phi*gamma_phi(log_m_phi)) / (4*E_space*1e6), m_nu, 0.002)
#      60 # print("E_1_min:", E_1_min)
# ---> 62 f_FD = lambda E_1:  1/(1+df.safe_exp(E_1/T_nu))
#      64 integ_part = lambda c, E_1: cross_section(E_space, log_m_phi, log_lambda_nu, c, E_1) * f_FD(E_1) * E_1**2/ (4*np.pi**2)
#      66 ratio = -df.gl2_integrate_vector(integ_part, [(-1, 1), (E_1_min, 0.002)], n=200)
#
# KeyboardInterrupt:

# %%
import SignalRate_1d as s1d
import numpy as np
from scipy.optimize import minimize
import definition as df

percision = 64
E_range = (5, 50)
t_range = (0.01, 30)

E_min, E_max = E_range
t_min, t_max = t_range

t_samples = np.load(r'F:/Neutrino_SI/Data/samples_HK_1d.npy')[:, 0]
E_samples = np.load(r'F:/Neutrino_SI/Data/samples_HK_1d.npy')[:, 1]

print('sample shape', t_samples.shape, E_samples.shape)

range_k = [t_range, E_range,  (-1, 1)]

def SR_HK(t, E_e, c, *args):

    R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu = args

    # N_K = 1.43e32 # for K-II

    N_K = 1.26e34 # for HK

    # eff_K = 0.932/np.sqrt(1+(34/(12-7*E_e+E_e**2))**2)        # This one is not well-fitted

    eff_K = 1

    ret = N_K * s1d.cs_at_c(c, s1d.E_nu(E_e, c)) * s1d.Flux_total(t, s1d.E_nu(E_e, c), R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu) * s1d.E_nu_at_E_e(E_e, c) * eff_K

    return ret

def param_set(log_m, log_lambda):
    return [12, 4.5, 4.5, 0.1, 2, 0.5, log_m, log_lambda]

def log_likelihood(log_m, log_lambda):

    fun1_K = lambda x: SR_HK(t_samples, x, 0, *param_set(log_m, log_lambda))

    part1_K = df.gl3_integrate(SR_HK, range_k, percision, args=param_set(log_m, log_lambda))

    part2_K = df.gl_integrate(fun1_K, E_min, E_max)

    part3_K = 0

    ret_K = -part1_K + np.sum(np.log(part3_K + part2_K))

    return ret_K


def chi_2(log_m, log_lambda):
    return -2 * log_likelihood(log_m, log_lambda)

print('baseline:', chi_2(-4, -12))
print(chi_2(1, -5.8))

print(log_likelihood(-4, -12))
print(log_likelihood(1, -5.8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 from scipy.optimize import minimize
#       4 import definition as df
# ----> 6 np.save(r'F:/Neutrino_SI/Data/samples_HK_1d.npy', np.array([t_samples, E_samples]).T)
#       8 percision = 64
#       9 E_range = (5, 50)
#
# NameError: name 't_samples' is not defined

# %%
import numpy as np
from scipy.optimize import minimize, root_scalar

# 1. Define your mass grid
log_m_vals = np.linspace(0, 3, 50) # 50 points between -1 and 4
log_lambda_95CL = []

for log_m in log_m_vals:
    # --- STEP A: Find the minimum chi_2 (best-fit log_lambda) ---
    # def obj_min(x):
    #     # x is an array, we extract the first element for log_lambda
    #     return chi_2(log_m, x[0])
        
    # # Initial guess for the best fit log_lambda. 
    # # (Adjust -5.0 if your expected coupling scale is vastly different)
    # res_min = minimize(obj_min, x0=[-6.0], method='L-BFGS-B', bounds=[(-10, -3)])
    
    # if not res_min.success:
    #     print(f"Warning: Minimization failed at log_m={log_m}")
    #     log_lambda_95CL.append(np.nan)
    #     continue
        
    # best_log_lambda = res_min.x[0]
    # chi2_min = res_min.fun

    best_log_lambda = -10
    chi2_min = chi_2(1, -10)
    # this is the benchmark of minimum chi_2

    upper_bracket = best_log_lambda + 6  # Adjust if you expect the limit to be higher than this.
    # --- STEP B: Find where Delta chi_2 = 3.84 ---
    target_chi2 = chi2_min + 3.84
    
    def root_func(l_lambda):
        return chi_2(log_m, l_lambda) - target_chi2
        
    try:
        # We are usually looking for the UPPER limit on a coupling.
        # So we search in a bracket starting from the minimum and going higher.
        # (If your limit is expected to be higher than best_log_lambda + 10, increase the upper bracket).
        res_root = root_scalar(root_func, bracket=[best_log_lambda, upper_bracket], method='brentq')
        print('best_log_lambda', best_log_lambda, 'log_m:', log_m, 'log_lambda:', res_root.root)
        log_lambda_95CL.append(res_root.root)
        
    except ValueError:
        # A ValueError usually means the target_chi2 wasn't found inside the bracket.
        print('best_log_lambda', best_log_lambda)
        print(f"Failed to bracket root at log_m = {log_m}. Check the bracket range.")
        log_lambda_95CL.append(np.nan)

# Convert to a numpy array for easy plotting
log_lambda_95CL = np.array(log_lambda_95CL)
print(log_lambda_95CL)
# Out:
# best_log_lambda -10 log_m: 0.0 log_lambda: -5.182370206217859
# best_log_lambda -10 log_m: 0.061224489795918366 log_lambda: -5.177481160621068
# best_log_lambda -10 log_m: 0.12244897959183673 log_lambda: -5.2010892814189
# best_log_lambda -10 log_m: 0.18367346938775508 log_lambda: -5.2162384396671815
# best_log_lambda -10 log_m: 0.24489795918367346 log_lambda: -5.216187993002419
# best_log_lambda -10 log_m: 0.30612244897959184 log_lambda: -5.262741053239581
# best_log_lambda -10 log_m: 0.36734693877551017 log_lambda: -5.283281980157105
# best_log_lambda -10 log_m: 0.42857142857142855 log_lambda: -5.317999295876947
# best_log_lambda -10 log_m: 0.4897959183673469 log_lambda: -5.340628374048898
# best_log_lambda -10 log_m: 0.5510204081632653 log_lambda: -5.354892686771106
# best_log_lambda -10 log_m: 0.6122448979591837 log_lambda: -5.379048929858683
# best_log_lambda -10 log_m: 0.673469387755102 log_lambda: -5.410149232304778
# best_log_lambda -10 log_m: 0.7346938775510203 log_lambda: -5.433638083025457
# best_log_lambda -10 log_m: 0.7959183673469388 log_lambda: -5.455878766040701
# best_log_lambda -10 log_m: 0.8571428571428571 log_lambda: -5.495617280165482
# best_log_lambda -10 log_m: 0.9183673469387755 log_lambda: -5.522318049753473
# best_log_lambda -10 log_m: 0.9795918367346939 log_lambda: -5.5379021311470735
# best_log_lambda -10 log_m: 1.0408163265306123 log_lambda: -5.56916683064244
# best_log_lambda -10 log_m: 1.1020408163265305 log_lambda: -5.5941415311423475
# best_log_lambda -10 log_m: 1.163265306122449 log_lambda: -5.627072592757354
# best_log_lambda -10 log_m: 1.2244897959183674 log_lambda: -5.653168500178463
# best_log_lambda -10 log_m: 1.2857142857142856 log_lambda: -5.684609540741702
# best_log_lambda -10 log_m: 1.346938775510204 log_lambda: -5.715684293155332
# best_log_lambda -10 log_m: 1.4081632653061225 log_lambda: -5.744003451746413
# best_log_lambda -10 log_m: 1.4693877551020407 log_lambda: -5.770270914014219
# best_log_lambda -10 log_m: 1.530612244897959 log_lambda: -5.791645724034702
# best_log_lambda -10 log_m: 1.5918367346938775 log_lambda: -5.8240504446020305
# best_log_lambda -10 log_m: 1.653061224489796 log_lambda: -5.853087110654442
# best_log_lambda -10 log_m: 1.7142857142857142 log_lambda: -5.879125951924335
# best_log_lambda -10 log_m: 1.7755102040816326 log_lambda: -5.900145125917023
# best_log_lambda -10 log_m: 1.836734693877551 log_lambda: -5.920575150270859
# best_log_lambda -10 log_m: 1.8979591836734693 log_lambda: -5.935330585410569
# best_log_lambda -10 log_m: 1.9591836734693877 log_lambda: -5.943233051803674
# best_log_lambda -10 log_m: 2.020408163265306 log_lambda: -5.9402093329939145
# best_log_lambda -10 log_m: 2.0816326530612246 log_lambda: -5.925188191359248
# best_log_lambda -10 log_m: 2.142857142857143 log_lambda: -5.894279535616031
# best_log_lambda -10 log_m: 2.204081632653061 log_lambda: -5.845543003527096
# best_log_lambda -10 log_m: 2.2653061224489797 log_lambda: -5.774052182534162
# best_log_lambda -10 log_m: 2.326530612244898 log_lambda: -5.677353448517461
# best_log_lambda -10 log_m: 2.387755102040816 log_lambda: -5.550107973270672
# best_log_lambda -10 log_m: 2.4489795918367347 log_lambda: -5.385224029871894
# best_log_lambda -10 log_m: 2.510204081632653 log_lambda: -5.171679921501984
# best_log_lambda -10 log_m: 2.571428571428571 log_lambda: -4.891077634985013
# best_log_lambda -10 log_m: 2.63265306122449 log_lambda: -4.504866750147887
# best_log_lambda -10
# Failed to bracket root at log_m = 2.693877551020408. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 2.7551020408163263. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 2.816326530612245. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 2.877551020408163. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 2.9387755102040813. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.0. Check the bracket range.
# [-5.18237021 -5.17748116 -5.20108928 -5.21623844 -5.21618799 -5.26274105
#  -5.28328198 -5.3179993  -5.34062837 -5.35489269 -5.37904893 -5.41014923
#  -5.43363808 -5.45587877 -5.49561728 -5.52231805 -5.53790213 -5.56916683
#  -5.59414153 -5.62707259 -5.6531685  -5.68460954 -5.71568429 -5.74400345
#  -5.77027091 -5.79164572 -5.82405044 -5.85308711 -5.87912595 -5.90014513
#  -5.92057515 -5.93533059 -5.94323305 -5.94020933 -5.92518819 -5.89427954
#  -5.845543   -5.77405218 -5.67735345 -5.55010797 -5.38522403 -5.17167992
#  -4.89107763 -4.50486675         nan         nan         nan         nan
#          nan         nan]

# %%
# save log_m_vals and log_lambda_95CL together to one .npy file
np.save(r'F:/Neutrino_SI/Data/m_lambda_space_1d.npy', np.array([log_m_vals, log_lambda_95CL]).T)
np.load(r'F:/Neutrino_SI/Data/m_lambda_space_1d.npy')  # Load the saved data to verify

log_m_vals, log_lambda_95CL = np.load(r'F:/Neutrino_SI/Data/m_lambda_space_osc_2d.npy').T

# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(10**log_m_vals, 10**log_lambda_95CL, label='95% CL Upper Limit')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$m_{\phi}$ (eV)')
ax.set_ylabel(r'$\lambda_{\phi\nu}$')
ax.set_xlim(1, 1e3)
ax.set_ylim(1e-9, 4e-5)
ax.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import definition as df
import SignalRate_2d as s2d
from Simulation_Spectrum import time_limit

t_range = (0.01, time_limit('max'))


t_samples = np.load(r'F:/Neutrino_SI/Data/samples_HK.npy')[:, 0]
E_samples = np.load(r'F:/Neutrino_SI/Data/samples_HK.npy')[:, 1]

def SR_HK(t, E_e, c, *args):

    R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu = args

    # N_K = 1.43e32 # for K-II

    N_K = 1.26e34 # for HK

    # eff_K = 0.932/np.sqrt(1+(34/(12-7*E_e+E_e**2))**2)        # This one is not well-fitted

    eff_K = 1

    ret = N_K * s2d.cs_at_c(c, s2d.E_nu(E_e, c)) * s2d.flux_2d(t, s2d.E_nu(E_e, c), R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu) * s2d.E_nu_at_E_e(E_e, c) * eff_K

    return ret

params_1 = [0, 0, 0, 0, 0, 0, -4, -12]
params_2 = [0, 0, 0, 0, 0, 0, 1.2244897959183674, -6.0228186190835595]
ranges: list = [(5, 50),  (-1, 1)]
bin_num = 50

integ_1 = lambda E, c, t: SR_HK(t, E, c, *params_1)
integ_2 = lambda E, c, t: SR_HK(t, E, c, *params_2)

t_space = np.linspace(t_range[0], t_range[1], 100)
y_1 = df.gl2_integrate_vec(integ_1, ranges, t_space)*t_range[1]/bin_num
# y_2 = df.gl2_integrate_vec(integ_2, ranges, t_space)*t_range[1]/bin_num

fig, ax = plt.subplots()
ax.hist(t_samples, bins=bin_num, alpha=0.5, label='Time Samples', color='blue', histtype = 'step')
ax.plot(t_space, y_1, label='SR at Samples', color = 'red', linestyle='--')
# ax.plot(t_space, y_2, label='SR at 95% CL', color = 'green', linestyle='--')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Signal Rate')
plt.legend()

fig
